# %% [markdown]
# ## Plotting Generator points

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
points = np.array([[1.5,1.0], [3.5,1.0], [5.0, 2.0], [2.5,3.0], [3.5,1.0],
                   [4.0, 4.0], [5.5,3.5], [6.0,5.5], [7.5,4.0], [1.6,6.0]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(points[:,0], points[:,1], 'o')
ax.set_xlim([-1,9])
ax.set_ylim([-1,9])
# Out:
# (-1.0, 9.0)

# %% [markdown]
# ## Plotting the Voronoi Diagram

# %%
from scipy.spatial import Voronoi, voronoi_plot_2d
vor = Voronoi(points)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(points[:,0], points[:,1], 'o')
ax.set_xlim([-1,9])
ax.set_ylim([-1,9])
voronoi_plot_2d(vor, ax)

# %% [markdown]
# ## Plotting a Delaunay triangulation

# %%
from scipy.spatial import Delaunay
tri = Delaunay(points)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(points[:,0], points[:,1], 'o')
ax.set_xlim([-1,9])
ax.set_ylim([-1,9])
ax.triplot(points[:,0], points[:,1], tri.simplices.copy())

# %% [markdown]
# ## Plotting both graphs

# %%
fig = plt.figure()
ax = fig.add_subplot('111')
ax.plot(points[:, 0], points[:, 1], 'o', color='k')
ax.set_xlim([-1, 9])
ax.set_ylim([-1, 9])
voronoi_plot_2d(vor, ax)
ax.triplot(points[:,0], points[:,1], tri.simplices.copy(), color='blue')
# Out:
# <ipython-input-15-acc3fbfff99a>:2: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot('111')
# ...
