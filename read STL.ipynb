# %%
import numpy
from stl import mesh

your_mesh = mesh.Mesh.from_file('cube.stl')

# %%
your_mesh.normals
# Out:
# array([[      0.  ,       0.  , -160000.02],
#        [-160000.  ,       0.  ,       0.  ],
#        [     -0.  ,      -0.  , -160000.02],
#        [      0.  ,  160000.02,       0.  ],
#        [-160000.  ,       0.  ,       0.  ],
#        [      0.  , -160000.02,      -0.  ],
#        [      0.  , -160000.02,       0.  ],
#        [ 160000.  ,       0.  ,       0.  ],
#        [ 160000.  ,      -0.  ,       0.  ],
#        [      0.  ,  160000.02,       0.  ],
#        [      0.  ,       0.  ,  160000.02],
#        [      0.  ,       0.  ,  160000.02]], dtype=float32)

# %%
your_mesh.v0, your_mesh.v1, your_mesh.v2
# Out:
# (array([[-252.37747,  -98.19032,    0.     ],
#         [-652.3775 ,  -98.19032,  400.     ],
#         [-252.37747,  301.8097 ,    0.     ],
#         [-652.3775 ,  301.8097 ,  400.     ],
#         [-652.3775 ,  -98.19032,  400.     ],
#         [-252.37747,  -98.19032,  400.     ],
#         [-652.3775 ,  -98.19032,  400.     ],
#         [-252.37747,  301.8097 ,  400.     ],
#         [-252.37747,  -98.19032,  400.     ],
#         [-252.37747,  301.8097 ,  400.     ],
#         [-652.3775 ,  -98.19032,  400.     ],
#         [-652.3775 ,  -98.19032,  400.     ]], dtype=float32),
#  array([[-652.3775 ,  -98.19032,    0.     ],
#         [-652.3775 ,  301.8097 ,    0.     ],
#         [-252.37747,  -98.19032,    0.     ],
#         [-252.37747,  301.8097 ,    0.     ],
#         [-652.3775 ,  301.8097 ,  400.     ],
#         [-652.3775 ,  -98.19032,    0.     ],
#         [-652.3775 ,  -98.19032,    0.     ],
#         [-252.37747,  -98.19032,    0.     ],
#         [-252.37747,  -98.19032,    0.     ],
#         [-252.37747,  301.8097 ,    0.     ],
#         [-252.37747,  301.8097 ,  400.     ],
#         [-252.37747,  -98.19032,  400.     ]], dtype=float32),
#  array([[-652.3775 ,  301.8097 ,    0.     ],
#         [-652.3775 ,  -98.19032,    0.     ],
#         [-652.3775 ,  301.8097 ,    0.     ],
#         [-652.3775 ,  301.8097 ,    0.     ],
#         [-652.3775 ,  301.8097 ,    0.     ],
#         [-252.37747,  -98.19032,    0.     ],
#         [-252.37747,  -98.19032,  400.     ],
#         [-252.37747,  301.8097 ,    0.     ],
#         [-252.37747,  301.8097 ,  400.     ],
#         [-652.3775 ,  301.8097 ,  400.     ],
#         [-652.3775 ,  301.8097 ,  400.     ],
#         [-252.37747,  301.8097 ,  400.     ]], dtype=float32))

# %%
from stl import mesh
from mpl_toolkits import mplot3d
from matplotlib import pyplot
# Create a new plot
figure = pyplot.figure()
axes = mplot3d.Axes3D(figure)
# Add the vectors to the plot
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(your_mesh.vectors))
# Auto scale to the mesh size
scale = your_mesh.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)
# Show the plot to the screen
pyplot.show()

# %%
pip install meshio
# Out:
# Collecting meshio
#   Downloading meshio-4.3.8-py3-none-any.whl (152 kB)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from meshio) (1.19.2)
# Installing collected packages: meshio
# Successfully installed meshio-4.3.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import meshio

# %%
meshio.read('cube.stl')
# Out:
# <meshio mesh object>
#   Number of points: 8
#   Number of cells:
#     triangle: 12

# %%
m = meshio.Mesh.read("cube.stl") 
m.write("foo.stl")

# %%
m
# Out:
# <meshio mesh object>
#   Number of points: 8
#   Number of cells:
#     triangle: 12
